# %%
import sys
sys.path.append("../../py_func_NoEnvReq") 
import databasepopulation
import communicationwmongo as commu
import home_location as home
import analysis as a
import pymongo
import my_h3_functions as myh3
import geopandas as gpd
import pandas as pd
from h3 import h3
import datetime
import os, inspect
import matplotlib.pyplot as plt
import importlib
importlib.reload(a)
# Out:
# <module 'analysis' from '../../py_func_NoEnvReq\\analysis.py'>

# %% [markdown]
# ## Objectives
#
# This notebook estimates a regression model to test the hypothesis that the growth trend of tweets in tracts in process of gentrification or at risk of gentrification were higher than in other tracts (already exclusionary tracts, etc.).
#
# I propose a baseline specification in logs (and levels) as follows :
# $$log(tweets) = \beta_0 t+\sum_j \delta_j t Dtypo_j + \sum_t Dyear_t+ \sum_j Dtypo_j + \epsilon $$
#
# Importantly we will use fixed effects to account for the aggregation periods in the data (quaterly).
#
# ## Procedure and instructions
#
# To run this notebook you will need the census tracts shapefiles and the corresponding census based typologies.
#
# You will first to set up a connection to the server where hex counts are stored.
#
# The code will first aggregate the hex level data into tract levels. For this the code will first join the tracts data into the hex-level data. This process involves a spatial join with the census tracts shapefile and also, with the typologies data. You might need to manually change the typologies categories to match the proposed analysis.
#
# The regression analysis is implemented with Statsmodels library. You might need to install this library if you do not have it in your local environment.

# %% [markdown]
# ## Step 0. Set up a Connection to the Mongo server using your credentials

# %%
uri = "mongodb://emmanuel:emaUCber@3.14.72.122:27017/twitter?authSource=twitter&readPreference=primary&appname=MongoDB%20Compass%20Community&ssl=false"
client = pymongo.MongoClient(uri)
db = client['sydney']

# %% [markdown]
# ## Step 1. Obtain the hex counts data and turn the geometry into centroids

# %%
# Get counts at hex level from the database 
df=a.hexcountsresults_to_df(db, save=False)

# %%
dfcentroids=myh3.df_with_hexid_to_centroids_gdf(df, hexcolname='_id')

# %%
# The following is a plot of the centroids of the hexhagons. It could be useful to check if coordinates are OK.
dfcentroids.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Step 2: (Spatially) join the tract level data.
#
# Be sure that projections match. The code proposes to reproject the input data for the standard epsg 4326 I also have to standarize the typologies to the ones in this project

# %%
# Spatial Join
# Change the reference to the census tract shapefile accordingly
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
tracts = gpd.read_file('C:/Users/emman/Box/Twitter data/Observation Shapefiles/syd.geojson')
tracts=tracts.to_crs({'init': 'epsg:4326'})
# Out:
# C:\Users\emman\AppData\Local\Continuum\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
tracts.rename(columns={'standardized_types':'TYPE'},inplace=True)

# %%
# Spatial Join between centroids and census track shapes
dfcentroids=gpd.sjoin(dfcentroids, tracts, how="inner", op='intersects')
# Out:
# C:\Users\emman\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: +init=epsg:4326 +type=crs

# %%
# As you can see in the final column of the next table, the data now incorporates the typologies
dfcentroids.head(3)
# Out:
#                _id        level_1  nonresidents  nonresidentsandnonneighbors  \
# 0  89be08182dbffff  1404086400000           1.0                          1.0
# 1  89be08184cbffff  1380499200000           1.0                          1.0
# 2  89be08186d3ffff  1419984000000           2.0                          2.0
#
#    residents  totalcounts       time                     geometry  \
# 0        NaN          1.0 2014-06-30  POINT (150.65147 -33.98392)
# 1        NaN          1.0 2013-09-30  POINT (150.65897 -34.02219)
# 2        NaN          2.0 2014-12-31  POINT (150.66951 -34.00514)
#
#    index_right SA2_MAIN16  ...      GCC_NAME16 STE_CODE16       STE_NAME16  \
# 0          258  127011506  ...  Greater Sydney          1  New South Wales
# 1          258  127011506  ...  Greater Sydney          1  New South Wales
# 2          258  127011506  ...  Greater Sydney          1  New South Wales
#
#   AREASQKM16  OID SA2_MAINCODE_2016 rentals_ov100_11 types  \
# 0   132.1375  224         127011506                1     1
# 1   132.1375  224         127011506                1     1
# 2   132.1375  224         127011506                1     1
#
#                 Typology_ID                TYPE
# 0  LI - Low Risk: Gent/Disp  Low Income, Stable
# 1  LI - Low Risk: Gent/Disp  Low Income, Stable
# 2  LI - Low Risk: Gent/Disp  Low Income, Stable
#
# [3 rows x 27 columns]

# %% [markdown]
# # Step 3: Aggregating the data at the tract and time level
#
# COD_2010 is the identifier of the tract level code id from Buenos Aires. Change it appropiately

# %%
df_tract_level=dfcentroids[['nonresidents','nonresidentsandnonneighbors','residents','totalcounts','SA2_MAIN16','time']].groupby(['SA2_MAIN16','time']).sum().reset_index()
typologies_code=dfcentroids[['SA2_MAIN16','TYPE']].drop_duplicates()
df_tract_level=df_tract_level.merge(typologies_code, left_on='SA2_MAIN16', right_on='SA2_MAIN16')
df_tract_level.head(5)
# Out:
#   SA2_MAIN16       time  nonresidents  nonresidentsandnonneighbors  residents  \
# 0  115011290 2012-09-30         298.0                        279.0       66.0
# 1  115011290 2012-12-31         329.0                        327.0      117.0
# 2  115011290 2013-03-31         609.0                        595.0       25.0
# 3  115011290 2013-06-30         664.0                        631.0      130.0
# 4  115011290 2013-09-30         564.0                        543.0      152.0
#
#    totalcounts              TYPE
# 0        364.0  Exclusive Static
# 1        446.0  Exclusive Static
# 2        634.0  Exclusive Static
# 3        794.0  Exclusive Static
# 4        716.0  Exclusive Static

# %%
df_tract_level.TYPE.unique()
# Out:
# array(['Exclusive Static', 'Exclusive Dynamic',
#        'Low Income, Undergoing Change', 'Low Income, At Risk of Change',
#        'Low Income, Stable'], dtype=object)

# %% [markdown]
# # Step 4: Insert the data to the DB
#
# Insert the resulting data into the Server, just to not repeat the complete process again in the future.

# %%
#db.tract_level_counts.insert_many(df_tract_level.to_dict('records'))

# %% [markdown]
# # Step 5: Regression Analysis

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# Use the first date in the dataset to compute the following count of number of days, which will serve to model the time trend. In the case of Buenos Aires it is 2012,9,30. Change appropiately

# %%
df_tract_level['days']=(df_tract_level.time-datetime.datetime(2012,9,30)).dt.days

# %% [markdown]
# Reproduce the following graphs to examine possible problems in the data

# %%
df_tract_level.plot.scatter(x='days',y='nonresidents')
#ojo voy a tener que controlar por la muestra porque el ultimo periodo tiene menos datos
# Out:
# <AxesSubplot:xlabel='days', ylabel='nonresidents'>

# %%
import numpy as np
df_tract_level['lognonresidents']=np.log(df_tract_level.nonresidents)
# Out:
# C:\Users\emman\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_tract_level.plot.scatter(x='days',y='lognonresidents')
# Out:
# <AxesSubplot:xlabel='days', ylabel='lognonresidents'>

# %%
df_tract_level.groupby('TYPE').count()
# Out:
#                                SA2_MAIN16  time  nonresidents  \
# TYPE
# Exclusive Dynamic                    1186  1186          1186
# Exclusive Static                     1241  1241          1241
# Low Income, At Risk of Change         936   936           936
# Low Income, Stable                    485   485           485
# Low Income, Undergoing Change         917   917           917
#
#                                nonresidentsandnonneighbors  residents  \
# TYPE
# Exclusive Dynamic                                     1186       1186
# Exclusive Static                                      1241       1241
# Low Income, At Risk of Change                          936        936
# Low Income, Stable                                     485        485
# Low Income, Undergoing Change                          917        917
#
#                                totalcounts  days  lognonresidents
# TYPE
# Exclusive Dynamic                     1186  1186             1186
# Exclusive Static                      1241  1241             1241
# Low Income, At Risk of Change          936   936              936
# Low Income, Stable                     485   485              485
# Low Income, Undergoing Change          917   917              917

# %% [markdown]
# The following lines implement the regression

# %%
datos=df_tract_level[['lognonresidents','nonresidents','days','TYPE','time','SA2_MAIN16']]
# el metodo dropna() me permite eliminar las filas que tienen algun valor missing
datos=datos.dropna()

# %%
datos=datos.loc[datos.nonresidents>0]

# %%
import numpy as np
results = smf.ols('lognonresidents ~  days*C(TYPE)+ C(time)', data=datos).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        lognonresidents   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     132.6
# Date:                Sat, 07 Nov 2020   Prob (F-statistic):               0.00
# Time:                        07:30:11   Log-Likelihood:                -7081.2
# No. Observations:                4497   AIC:                         1.421e+04
# Df Residuals:                    4472   BIC:                         1.437e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                         5.6437      0.092     61.616      0.000       5.464       5.823
# C(TYPE)[T.Exclusive Static]                       0.6100      0.091      6.672      0.000       0.431       0.789
# C(TYPE)[T.Low Income, At Risk of Change]          0.7409      0.098      7.526      0.000       0.548       0.934
# C(TYPE)[T.Low Income, Stable]                     0.2642      0.121      2.177      0.030       0.026       0.502
# C(TYPE)[T.Low Income, Undergoing Change]          0.4753      0.099      4.801      0.000       0.281       0.669
# C(time)[T.Timestamp('2012-12-31 00:00:00')]       0.5073      0.097      5.206      0.000       0.316       0.698
# C(time)[T.Timestamp('2013-03-31 00:00:00')]       0.7447      0.093      7.977      0.000       0.562       0.928
# C(time)[T.Timestamp('2013-06-30 00:00:00')]       0.6532      0.089      7.304      0.000       0.478       0.829
# C(time)[T.Timestamp('2013-09-30 00:00:00')]       0.7523      0.086      8.778      0.000       0.584       0.920
# C(time)[T.Timestamp('2013-12-31 00:00:00')]       1.2460      0.082     15.151      0.000       1.085       1.407
# C(time)[T.Timestamp('2014-03-31 00:00:00')]       1.0685      0.079     13.500      0.000       0.913       1.224
# C(time)[T.Timestamp('2014-06-30 00:00:00')]       1.0241      0.076     13.411      0.000       0.874       1.174
# C(time)[T.Timestamp('2014-09-30 00:00:00')]       0.8353      0.074     11.298      0.000       0.690       0.980
# C(time)[T.Timestamp('2014-12-31 00:00:00')]       0.8742      0.072     12.155      0.000       0.733       1.015
# C(time)[T.Timestamp('2015-03-31 00:00:00')]       1.0892      0.070     15.471      0.000       0.951       1.227
# C(time)[T.Timestamp('2015-06-30 00:00:00')]       0.5657      0.069      8.158      0.000       0.430       0.702
# C(time)[T.Timestamp('2015-09-30 00:00:00')]      -0.5857      0.069     -8.516      0.000      -0.720      -0.451
# C(time)[T.Timestamp('2016-03-31 00:00:00')]      -0.7018      0.069    -10.108      0.000      -0.838      -0.566
# C(time)[T.Timestamp('2016-06-30 00:00:00')]      -0.7724      0.070    -11.004      0.000      -0.910      -0.635
# C(time)[T.Timestamp('2016-09-30 00:00:00')]      -0.4967      0.072     -6.911      0.000      -0.638      -0.356
# C(time)[T.Timestamp('2016-12-31 00:00:00')]      -1.2944      0.074    -17.499      0.000      -1.439      -1.149
# days                                             -0.0002   9.55e-05     -1.838      0.066      -0.000    1.17e-05
# days:C(TYPE)[T.Exclusive Static]                 -0.0002      0.000     -2.334      0.020      -0.000   -3.84e-05
# days:C(TYPE)[T.Low Income, At Risk of Change]    -0.0005      0.000     -4.615      0.000      -0.001      -0.000
# days:C(TYPE)[T.Low Income, Stable]               -0.0006      0.000     -4.376      0.000      -0.001      -0.000
# days:C(TYPE)[T.Low Income, Undergoing Change]    -0.0006      0.000     -5.811      0.000      -0.001      -0.000
# ==============================================================================
# Omnibus:                      151.484   Durbin-Watson:                   0.330
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              367.625
# Skew:                           0.153   Prob(JB):                     1.48e-80
# Kurtosis:                       4.367   Cond. No.                     2.85e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.08e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import numpy as np
results = smf.ols('lognonresidents ~  days*C(TYPE)+ C(time)', data=datos).fit(cov_type="cluster",cov_kwds={"groups":datos['TYPE']})
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        lognonresidents   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     136.4
# Date:                Sat, 07 Nov 2020   Prob (F-statistic):           0.000158
# Time:                        07:30:12   Log-Likelihood:                -7081.2
# No. Observations:                4497   AIC:                         1.421e+04
# Df Residuals:                    4472   BIC:                         1.437e+04
# Df Model:                          24
# Covariance Type:              cluster
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                         5.6437      0.052    109.482      0.000       5.543       5.745
# C(TYPE)[T.Exclusive Static]                       0.6100   4.34e-05    1.4e+04      0.000       0.610       0.610
# C(TYPE)[T.Low Income, At Risk of Change]          0.7409   9.95e-05   7444.388      0.000       0.741       0.741
# C(TYPE)[T.Low Income, Stable]                     0.2642      0.000   1761.961      0.000       0.264       0.264
# C(TYPE)[T.Low Income, Undergoing Change]          0.4753   3.54e-05   1.34e+04      0.000       0.475       0.475
# C(time)[T.Timestamp('2012-12-31 00:00:00')]       0.5073      0.009     56.564      0.000       0.490       0.525
# C(time)[T.Timestamp('2013-03-31 00:00:00')]       0.7447      0.027     27.600      0.000       0.692       0.798
# C(time)[T.Timestamp('2013-06-30 00:00:00')]       0.6532      0.052     12.510      0.000       0.551       0.756
# C(time)[T.Timestamp('2013-09-30 00:00:00')]       0.7523      0.051     14.850      0.000       0.653       0.852
# C(time)[T.Timestamp('2013-12-31 00:00:00')]       1.2460      0.055     22.472      0.000       1.137       1.355
# C(time)[T.Timestamp('2014-03-31 00:00:00')]       1.0685      0.048     22.247      0.000       0.974       1.163
# C(time)[T.Timestamp('2014-06-30 00:00:00')]       1.0241      0.032     31.549      0.000       0.961       1.088
# C(time)[T.Timestamp('2014-09-30 00:00:00')]       0.8353      0.063     13.239      0.000       0.712       0.959
# C(time)[T.Timestamp('2014-12-31 00:00:00')]       0.8742      0.064     13.598      0.000       0.748       1.000
# C(time)[T.Timestamp('2015-03-31 00:00:00')]       1.0892      0.064     17.020      0.000       0.964       1.215
# C(time)[T.Timestamp('2015-06-30 00:00:00')]       0.5657      0.048     11.739      0.000       0.471       0.660
# C(time)[T.Timestamp('2015-09-30 00:00:00')]      -0.5857      0.051    -11.469      0.000      -0.686      -0.486
# C(time)[T.Timestamp('2016-03-31 00:00:00')]      -0.7018      0.060    -11.647      0.000      -0.820      -0.584
# C(time)[T.Timestamp('2016-06-30 00:00:00')]      -0.7724      0.032    -24.345      0.000      -0.835      -0.710
# C(time)[T.Timestamp('2016-09-30 00:00:00')]      -0.4967      0.032    -15.699      0.000      -0.559      -0.435
# C(time)[T.Timestamp('2016-12-31 00:00:00')]      -1.2944      0.067    -19.267      0.000      -1.426      -1.163
# days                                             -0.0002   4.88e-05     -3.599      0.000      -0.000      -8e-05
# days:C(TYPE)[T.Exclusive Static]                 -0.0002   1.24e-07  -1943.352      0.000      -0.000      -0.000
# days:C(TYPE)[T.Low Income, At Risk of Change]    -0.0005   2.44e-07  -2095.520      0.000      -0.001      -0.001
# days:C(TYPE)[T.Low Income, Stable]               -0.0006   3.66e-07  -1636.621      0.000      -0.001      -0.001
# days:C(TYPE)[T.Low Income, Undergoing Change]    -0.0006   9.84e-08  -6580.030      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                      151.484   Durbin-Watson:                   0.330
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              367.625
# Skew:                           0.153   Prob(JB):                     1.48e-80
# Kurtosis:                       4.367   Cond. No.                     2.85e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 5.08e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\emman\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:1834: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 25, but rank is 4
#   'rank is %d' % (J, J_), ValueWarning)

# %%
import numpy as np
results2 = smf.ols('lognonresidents ~  days*C(TYPE)', data=datos).fit(cov_type="cluster",cov_kwds={"groups":datos['TYPE']})
print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        lognonresidents   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                 1.274e+26
# Date:                Sat, 07 Nov 2020   Prob (F-statistic):           1.73e-52
# Time:                        07:30:12   Log-Likelihood:                -7570.5
# No. Observations:                4497   AIC:                         1.516e+04
# Df Residuals:                    4487   BIC:                         1.523e+04
# Df Model:                           9
# Covariance Type:              cluster
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                         6.7725   5.89e-15   1.15e+15      0.000       6.772       6.772
# C(TYPE)[T.Exclusive Static]                       0.6104   1.24e-13   4.93e+12      0.000       0.610       0.610
# C(TYPE)[T.Low Income, At Risk of Change]          0.7423   1.33e-13   5.57e+12      0.000       0.742       0.742
# C(TYPE)[T.Low Income, Stable]                     0.2621   3.64e-14    7.2e+12      0.000       0.262       0.262
# C(TYPE)[T.Low Income, Undergoing Change]          0.4754   2.28e-14   2.08e+13      0.000       0.475       0.475
# days                                             -0.0012   3.07e-16  -4.06e+12      0.000      -0.001      -0.001
# days:C(TYPE)[T.Exclusive Static]                 -0.0002   3.15e-16  -7.67e+11      0.000      -0.000      -0.000
# days:C(TYPE)[T.Low Income, At Risk of Change]    -0.0005   3.08e-16  -1.67e+12      0.000      -0.001      -0.001
# days:C(TYPE)[T.Low Income, Stable]               -0.0006   5.07e-16  -1.17e+12      0.000      -0.001      -0.001
# days:C(TYPE)[T.Low Income, Undergoing Change]    -0.0006   3.38e-16  -1.92e+12      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                       34.812   Durbin-Watson:                   0.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.175
# Skew:                          -0.046   Prob(JB):                     4.68e-12
# Kurtosis:                       3.519   Cond. No.                     9.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The condition number is large, 9.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\emman\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:1834: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 9, but rank is 5
#   'rank is %d' % (J, J_), ValueWarning)

# %%
results.params, results.bse
# Out:
# (Intercept                                        5.643738
#  C(TYPE)[T.Exclusive Static]                      0.610011
#  C(TYPE)[T.Low Income, At Risk of Change]         0.740930
#  C(TYPE)[T.Low Income, Stable]                    0.264160
#  C(TYPE)[T.Low Income, Undergoing Change]         0.475310
#  C(time)[T.Timestamp('2012-12-31 00:00:00')]      0.507266
#  C(time)[T.Timestamp('2013-03-31 00:00:00')]      0.744689
#  C(time)[T.Timestamp('2013-06-30 00:00:00')]      0.653185
#  C(time)[T.Timestamp('2013-09-30 00:00:00')]      0.752252
#  C(time)[T.Timestamp('2013-12-31 00:00:00')]      1.245958
#  C(time)[T.Timestamp('2014-03-31 00:00:00')]      1.068529
#  C(time)[T.Timestamp('2014-06-30 00:00:00')]      1.024137
#  C(time)[T.Timestamp('2014-09-30 00:00:00')]      0.835270
#  C(time)[T.Timestamp('2014-12-31 00:00:00')]      0.874223
#  C(time)[T.Timestamp('2015-03-31 00:00:00')]      1.089177
#  C(time)[T.Timestamp('2015-06-30 00:00:00')]      0.565691
#  C(time)[T.Timestamp('2015-09-30 00:00:00')]     -0.585666
#  C(time)[T.Timestamp('2016-03-31 00:00:00')]     -0.701752
#  C(time)[T.Timestamp('2016-06-30 00:00:00')]     -0.772424
#  C(time)[T.Timestamp('2016-09-30 00:00:00')]     -0.496690
#  C(time)[T.Timestamp('2016-12-31 00:00:00')]     -1.294398
#  days                                            -0.000176
#  days:C(TYPE)[T.Exclusive Static]                -0.000240
#  days:C(TYPE)[T.Low Income, At Risk of Change]   -0.000511
#  days:C(TYPE)[T.Low Income, Stable]              -0.000599
#  days:C(TYPE)[T.Low Income, Undergoing Change]   -0.000647
#  dtype: float64,
#  Intercept                                        5.154924e-02
#  C(TYPE)[T.Exclusive Static]                      4.344320e-05
#  C(TYPE)[T.Low Income, At Risk of Change]         9.952864e-05
#  C(TYPE)[T.Low Income, Stable]                    1.499241e-04
#  C(TYPE)[T.Low Income, Undergoing Change]         3.539166e-05
#  C(time)[T.Timestamp('2012-12-31 00:00:00')]      8.967969e-03
#  C(time)[T.Timestamp('2013-03-31 00:00:00')]      2.698111e-02
#  C(time)[T.Timestamp('2013-06-30 00:00:00')]      5.221297e-02
#  C(time)[T.Timestamp('2013-09-30 00:00:00')]      5.065827e-02
#  C(time)[T.Timestamp('2013-12-31 00:00:00')]      5.544515e-02
#  C(time)[T.Timestamp('2014-03-31 00:00:00')]      4.803113e-02
#  C(time)[T.Timestamp('2014-06-30 00:00:00')]      3.246153e-02
#  C(time)[T.Timestamp('2014-09-30 00:00:00')]      6.309219e-02
#  C(time)[T.Timestamp('2014-12-31 00:00:00')]      6.428852e-02
#  C(time)[T.Timestamp('2015-03-31 00:00:00')]      6.399395e-02
#  C(time)[T.Timestamp('2015-06-30 00:00:00')]      4.818939e-02
#  C(time)[T.Timestamp('2015-09-30 00:00:00')]      5.106353e-02
#  C(time)[T.Timestamp('2016-03-31 00:00:00')]      6.025335e-02
#  C(time)[T.Timestamp('2016-06-30 00:00:00')]      3.172796e-02
#  C(time)[T.Timestamp('2016-09-30 00:00:00')]      3.163921e-02
#  C(time)[T.Timestamp('2016-12-31 00:00:00')]      6.718082e-02
#  days                                             4.877975e-05
#  days:C(TYPE)[T.Exclusive Static]                 1.235785e-07
#  days:C(TYPE)[T.Low Income, At Risk of Change]    2.439804e-07
#  days:C(TYPE)[T.Low Income, Stable]               3.657371e-07
#  days:C(TYPE)[T.Low Income, Undergoing Change]    9.839659e-08
#  dtype: float64)

# %%
varnames_to_print=['Intercept', 'C(TYPE)[T.Exclusive Static]',
       'C(TYPE)[T.Low Income, At Risk of Change]',
       'C(TYPE)[T.Low Income, Undergoing Change]', 'days',
       'days:C(TYPE)[T.Exclusive Static]',
       'days:C(TYPE)[T.Low Income, At Risk of Change]',
       'days:C(TYPE)[T.Low Income, Undergoing Change]']



labels_dict={'C(TYPE)[T.Exclusive Static]':'Exclusive Static', 
             'C(TYPE)[T.Low Income, Undergoing Change]': 'Low Income, Undergoing Change',
             'C(TYPE)[T.Low Income, At Risk of Change]': 'Low Income, At Risk of Change',
             'days:C(TYPE)[T.Exclusive Static]':'T * Exclusive Static',
       'days:C(TYPE)[T.Low Income, At Risk of Change]': 'T * Low Income, At Risk of Change',
       'days:C(TYPE)[T.Low Income, Undergoing Change]': 'T * Low Income, Undergoing Change',
             'days':'T',
             
            }

# %% [markdown]
# # New Function Run (11/07/2020)
#
# I believe that the fvalue function no longer needs to be subscripted ([0][0])

# %%
def to_summary_table(varnames_to_print, listofresults, labels_dict=None, specialrows=None):
    
    """ Transforms list of statsmodels results to publication style printing 
    
    varnames_to_print: These are the actual variable names in the regression output
    list of results: list of results, results are statsmodels result objects 
    labels_dict: Optional, will change the variable to those provided
    returns: dataframe
    
    """
    
    vars_names=[]


    # The idea is to create a list of contents for each column

    # First column
    row=0
    for var in varnames_to_print:  
        # contenido de la 1ra fila
        
        if labels_dict is not None and var in labels_dict:  
            vars_names.append(labels_dict[var]) 
        else:
            vars_names.append(var) 
        
        row+=1
        vars_names.append('')
        row+=1
    
    
    if specialrows is not None:
        for varname in specialrows:
            vars_names.append(varname['varname'])
    # LISTA DE ESTADISTICOS DEL FINAL DE TABLA
    vars_names.append('Number of obs.')
    vars_names.append('Adj-R2')
    vars_names.append('F-statistic:')
    vars_names.append('Prob (F-statistic)')
    
    
    


    # 
    data = {0: vars_names}
    
    column=1
    for results in listofresults:  #Loop for each column (each list of passed results)
        coefficients=[]
        standard_errors=[]
        row=0
        
        for var in varnames_to_print:   

            if var in results.pvalues:
                if results.pvalues[var]<=0.01:
                    asterisk='***'
                elif results.pvalues[var]<=0.05:
                    asterisk='**'
                elif results.pvalues[var]<=0.1:
                    asterisk='*'
                else:
                    asterisk=''

                coefficients.append(   str(round(results.params[var],4)) + asterisk)
                row+=1

                # contenido de la 2da fila

                coefficients.append('('+str(round(results.bse[var],4))+')')
                row+=1
            else:  #la variable no esta en esa especificacion
                coefficients.append(' ')
                row+=1
                # contenido de la 2da fila
                coefficients.append(' ')
                row+=1
        
        if specialrows is not None:
            for varname in specialrows:
                coefficients.append(varname['values'][column-1])
            
        # PASAR LA LISTA DE ESTADISTICOS DEL FINAL DE TABLA EN EL MISMO ORDEN QUE ARRIBA
        coefficients.append(results.nobs)
        coefficients.append(round(results.rsquared_adj,3))
        coefficients.append(np.round(results.fvalue,3)) 
        coefficients.append(np.round(results.f_pvalue,3))
        
        
        data[column]=coefficients
        column+=1
    
    
    

    
    return pd.DataFrame.from_dict(data)






specialrows=[{'varname':'Time aggregation Dummies', 'values':['Yes','No']}]
printabletable=to_summary_table(varnames_to_print, [results, results2],labels_dict, specialrows)
printabletable
# Out:
#                                     0           1           2
# 0                           Intercept   5.6437***   6.7725***
# 1                                        (0.0515)       (0.0)
# 2                    Exclusive Static     0.61***   0.6104***
# 3                                           (0.0)       (0.0)
# 4       Low Income, At Risk of Change   0.7409***   0.7423***
# 5                                        (0.0001)       (0.0)
# 6       Low Income, Undergoing Change   0.4753***   0.4754***
# 7                                           (0.0)       (0.0)
# 8                                   T  -0.0002***  -0.0012***
# 9                                           (0.0)       (0.0)
# 10               T * Exclusive Static  -0.0002***  -0.0002***
# 11                                          (0.0)       (0.0)
# 12  T * Low Income, At Risk of Change  -0.0005***  -0.0005***
# 13                                          (0.0)       (0.0)
# 14  T * Low Income, Undergoing Change  -0.0006***  -0.0006***
# 15                                          (0.0)       (0.0)
# 16           Time aggregation Dummies         Yes          No
# 17                     Number of obs.        4497        4497
# 18                             Adj-R2       0.413       0.272
# 19                       F-statistic:     136.364  1.2737e+26
# 20                 Prob (F-statistic)           0           0

# %% [markdown]
# # Old Function (10/28/2020)

# %%
def to_summary_table(varnames_to_print, listofresults, labels_dict=None, specialrows=None):
    
    """ Transforms list of statsmodels results to publication style printing 
    
    varnames_to_print: These are the actual variable names in the regression output
    list of results: list of results, results are statsmodels result objects 
    labels_dict: Optional, will change the variable to those provided
    returns: dataframe
    
    """
    
    vars_names=[]


    # The idea is to create a list of contents for each column

    # First column
    row=0
    for var in varnames_to_print:  
        # contenido de la 1ra fila
        
        if labels_dict is not None and var in labels_dict:  
            vars_names.append(labels_dict[var]) 
        else:
            vars_names.append(var) 
        
        row+=1
        vars_names.append('')
        row+=1
    
    
    if specialrows is not None:
        for varname in specialrows:
            vars_names.append(varname['varname'])
    # LISTA DE ESTADISTICOS DEL FINAL DE TABLA
    vars_names.append('Number of obs.')
    vars_names.append('Adj-R2')
    vars_names.append('F-statistic:')
    vars_names.append('Prob (F-statistic)')
    
    
    


    # 
    data = {0: vars_names}
    
    column=1
    for results in listofresults:  #Loop for each column (each list of passed results)
        coefficients=[]
        standard_errors=[]
        row=0
        
        for var in varnames_to_print:   

            if var in results.pvalues:
                if results.pvalues[var]<=0.01:
                    asterisk='***'
                elif results.pvalues[var]<=0.05:
                    asterisk='**'
                elif results.pvalues[var]<=0.1:
                    asterisk='*'
                else:
                    asterisk=''

                coefficients.append(   str(round(results.params[var],4)) + asterisk)
                row+=1

                # contenido de la 2da fila

                coefficients.append('('+str(round(results.bse[var],4))+')')
                row+=1
            else:  #la variable no esta en esa especificacion
                coefficients.append(' ')
                row+=1
                # contenido de la 2da fila
                coefficients.append(' ')
                row+=1
        
        if specialrows is not None:
            for varname in specialrows:
                coefficients.append(varname['values'][column-1])
            
        # PASAR LA LISTA DE ESTADISTICOS DEL FINAL DE TABLA EN EL MISMO ORDEN QUE ARRIBA
        coefficients.append(results.nobs)
        coefficients.append(round(results.rsquared_adj,3))
        coefficients.append(np.round(results.fvalue[0][0],3))
        coefficients.append(np.round(results.f_pvalue,3))
        
        
        data[column]=coefficients
        column+=1
    
    
    

    
    return pd.DataFrame.from_dict(data)






specialrows=[{'varname':'Time aggregation Dummies', 'values':['Yes','No']}]
printabletable=to_summary_table(varnames_to_print, [results, results2],labels_dict, specialrows)
printabletable
# Out:
#                                     0           1           2
# 0                           Intercept   5.6437***   6.7725***
# 1                                        (0.0515)       (0.0)
# 2                    Exclusive Static     0.61***   0.6104***
# 3                                           (0.0)       (0.0)
# 4       Low Income, At Risk of Change   0.7409***   0.7423***
# 5                                        (0.0001)       (0.0)
# 6       Low Income, Undergoing Change   0.4753***   0.4754***
# 7                                           (0.0)       (0.0)
# 8                                   T  -0.0002***  -0.0012***
# 9                                           (0.0)       (0.0)
# 10               T * Exclusive Static  -0.0002***  -0.0002***
# 11                                          (0.0)       (0.0)
# 12  T * Low Income, At Risk of Change  -0.0005***  -0.0005***
# 13                                          (0.0)       (0.0)
# 14  T * Low Income, Undergoing Change  -0.0006***  -0.0006***
# 15                                          (0.0)       (0.0)
# 16           Time aggregation Dummies         Yes          No
# 17                     Number of obs.        4497        4497
# 18                             Adj-R2       0.413       0.272
# 19                       F-statistic:     136.364  1.2737e+26
# 20                 Prob (F-statistic)           0           0

# %%
#Export results to CSV
printabletable.to_csv(currentdir+"regressions_buenos_aires.csv")
